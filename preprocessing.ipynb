# %%
import re
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# %%
df_data_covid_19 = pd.read_csv('data/corona_fake.csv')
print(df_data_covid_19.shape)
print(df_data_covid_19.columns)
# Out:
# (1164, 4)
# Index(['title', 'text', 'source', 'label'], dtype='object')

# %%
df_data_covid_19.head(10)
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  CORONA UNMASKED: Chinese Intelligence Officer ...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Basic protective measures against the new coro...
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
# 5                                                NaN
# 6  Urgent: Health Bulletin to the Public. Ministr...
# 7  Pls tell ur families, relatives and friendsMOH...
# 8  SERIOUS EXCELLENT ADVICE by Japanese doctors t...
# 9  Stay aware of the latest information on the CO...
#
#                                               source label
# 0                          coronavirusmedicalkit.com  Fake
# 1                                       RudyGiuliani  Fake
# 2                                        CharlieKirk  Fake
# 3                            JoanneWrightForCongress  Fake
# 4                            JoanneWrightForCongress  Fake
# 5                                                NaN   NaN
# 6                                 Ministry of Health  Fake
# 7                                             NWLLAB  Fake
# 8           Japanese doctors treating COVID-19 cases  Fake
# 9  https://www.who.int/emergencies/diseases/novel...  TRUE

# %%
def remove_none_column(df):
    # the number of those missing values from each column.
    print("number of missing title\t:", df[df['title'].isna()].shape[0])
    print("number of missing text\t:", df[df['text'].isna()].shape[0])
    print("number of missing source\t:", df[df['source'].isna()].shape[0])
    print("number of missing label\t:", df[df['label'].isna()].shape[0])
    # Remove all columns that contain None
    return df.dropna()

df_data_covid_19=remove_none_column(df_data_covid_19)
print(df_data_covid_19['label'].unique())
# Out:
# number of missing title	: 82
# number of missing text	: 10
# number of missing source	: 20
# number of missing label	: 5
# ['Fake' 'TRUE' 'fake']

# %%
def arranging_label_column(df):
    # Convert the word fake to the word FAKE
    df.loc[df['label'] == 'fake', 'label'] = 'FAKE'
    df.loc[df['label'] == 'Fake', 'label'] = 'FAKE'
    print('number_of_fakes: ', df.loc[df['label'] == 'FAKE'].count()[0])
    print('number_of_trues: ', df.loc[df['label'] == 'TRUE'].count()[0])
    return df

df_data_covid_19=arranging_label_column(df_data_covid_19)
print(df_data_covid_19['label'].unique())
# Out:
# number_of_fakes:  480
# number_of_trues:  579
# ['FAKE' 'TRUE']

# %%
df_data_covid_19.head(10)
# Out:
#                                                 title  \
# 0   Due to the recent outbreak for the Coronavirus...
# 9   Basic protective measures against the new coro...
# 14  Exposing yourself to the sun or to temperature...
# 16  Being able to hold your breath for 10 seconds ...
# 17  Drinking alcohol does not protect you against ...
# 18  COVID-19 virus can be transmitted in areas wit...
# 19  Cold weather and snow CANNOT kill the new coro...
# 20  Taking a hot bath does not prevent the new cor...
# 21  The new coronavirus CANNOT be transmitted thro...
# 22  Are hand dryers effective in killing the new c...
#
#                                                  text  \
# 0   You just need to add water, and the drugs and ...
# 9   Stay aware of the latest information on the CO...
# 14  You can catch COVID-19, no matter how sunny or...
# 16  The most common symptoms of COVID-19 are dry c...
# 17  Frequent or excessive alcohol consumption can ...
# 18  From the evidence so far, the COVID-19 virus c...
# 19  There is no reason to believe that cold weathe...
# 20  Taking a hot bath will not prevent you from ca...
# 21  To date there has been no information nor evid...
# 22  No. Hand dryers are not effective in killing t...
#
#                                                source label
# 0                           coronavirusmedicalkit.com  FAKE
# 9   https://www.who.int/emergencies/diseases/novel...  TRUE
# 14  https://www.who.int/emergencies/diseases/novel...  TRUE
# 16  https://www.who.int/emergencies/diseases/novel...  TRUE
# 17  https://www.who.int/emergencies/diseases/novel...  TRUE
# 18  https://www.who.int/emergencies/diseases/novel...  TRUE
# 19  https://www.who.int/emergencies/diseases/novel...  TRUE
# 20  https://www.who.int/emergencies/diseases/novel...  TRUE
# 21  https://www.who.int/emergencies/diseases/novel...  TRUE
# 22  https://www.who.int/emergencies/diseases/novel...  TRUE

# %% [markdown]
# ## Text preprocessing

# %%
def data_clearing(text):
    # Lowering letters
    text = text.lower()
    # Removing html tags
    text = re.sub(r'<[^>]*>', '', text)
    # Removing twitter usernames
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    # Removing urls
    text = re.sub('https?://[A-Za-z0-9]', '', text)
    # Removing numbers
    text = re.sub('[^a-zA-Z]', ' ', text)
    # distribution of tokens
    word_tokens = word_tokenize(text)
    # remove stopwords
    filtered_sentence = [word_token for word_token in word_tokens if word_token not in stop_words ]
    # Joining words
    text = (' '.join(filtered_sentence))
    
    return text

# %%
# Implement a cline function on the entire dataframe
for col_name in df_data_covid_19.columns:
    df_data_covid_19[col_name] = df_data_covid_19[col_name].apply(data_clearing)

# %%
df_data_covid_19.head(10)
# Out:
#                                                 title  \
# 0   due recent outbreak coronavirus covid world he...
# 9           basic protective measures new coronavirus
# 14  exposing sun temperatures higher c degrees pre...
# 16  able hold breath seconds without coughing feel...
# 17           drinking alcohol protect covid dangerous
# 18   covid virus transmitted areas hot humid climates
# 19             cold weather snow kill new coronavirus
# 20    taking hot bath prevent new coronavirus disease
# 21         new coronavirus transmitted mosquito bites
# 22      hand dryers effective killing new coronavirus
#
#                                                  text  \
# 0   need add water drugs vaccines ready administer...
# 9   stay aware latest information covid outbreak a...
# 14  catch covid matter sunny hot weather countries...
# 16  common symptoms covid dry cough tiredness feve...
# 17  frequent excessive alcohol consumption increas...
# 18  evidence far covid virus transmitted areas inc...
# 19  reason believe cold weather kill new coronavir...
# 20  taking hot bath prevent catching covid normal ...
# 21  date information evidence suggest new coronavi...
# 22  hand dryers effective killing ncov protect new...
#
#                                                source label
# 0                           coronavirusmedicalkit com  fake
# 9   ww int emergencies diseases novel coronavirus ...  true
# 14  ww int emergencies diseases novel coronavirus ...  true
# 16  ww int emergencies diseases novel coronavirus ...  true
# 17  ww int emergencies diseases novel coronavirus ...  true
# 18  ww int emergencies diseases novel coronavirus ...  true
# 19  ww int emergencies diseases novel coronavirus ...  true
# 20  ww int emergencies diseases novel coronavirus ...  true
# 21  ww int emergencies diseases novel coronavirus ...  true
# 22  ww int emergencies diseases novel coronavirus ...  true

# %%
df_data_covid_19.to_csv ('data/preprocessing.csv', index = False, header=True)
